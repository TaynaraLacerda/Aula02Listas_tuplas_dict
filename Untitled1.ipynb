# %% [markdown]
# <a href="https://colab.research.google.com/github/TaynaraLacerda/Aula02Listas_tuplas_dict/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Atividade Lista, Tuplas e Dicionário

# %% [markdown]
# Atividade 1:

# %%
materias = ['Matemática', 'História', 'Biologia']
notas = (8.5, 7.0, 9.2)
informacoes_do_aluno = {'nome': 'Carlos', 'idade': 21, 'curso': 'Engenharia'}
print("Matérias:", materias)
print("Notas:", notas)
print("Informações do aluno:", informacoes_do_aluno)
# Out:
# Matérias: ['Matemática', 'História', 'Biologia']
# Notas: (8.5, 7.0, 9.2)
# Informações do aluno: {'nome': 'Carlos', 'idade': 21, 'curso': 'Engenharia'}

# %% [markdown]
# Atividade 2:

# %%
acessorios = ['tapetes', 'alarme', 'capas de banco']
especificacoes = (1,2)
capacidade_do_tanque_de_combustivel = {45 ,55}
marca = ['Toyota']
modelo = ('Hillux')
ano = {2025}
print("Acessórios:", acessorios)
print("Especificações:", especificacoes)
print("Capacidade do tanque de combustivel:", capacidade_do_tanque_de_combustivel)
print("Marca:",marca)
print("Modelo:", modelo)
print("Ano:", 2025)
# Out:
# Acessórios: ['tapetes', 'alarme', 'capas de banco']
# Especificações: (1, 2)
# Capacidade do tanque de combustivel: {45, 55}
# Marca: ['Toyota']
# Modelo: Hillux
# Ano: 2025

# %% [markdown]
# Atividade 3:

# %%
categorias = ['Celular, Notebook, Computador']
especificacoes = ['Preço','Quantidade em estoque']
nome = {'empresa':'Senai_Story',
        'marca': 'ti',
    'ano': 2025
}
print("Categórias:", categorias)
print("Especificações:", especificacoes)
print("Nome:", nome)
print("Marca:",marca)
print("Ano:", ano)
# Out:
# Categórias: ['Celular, Notebook, Computador']
# Especificações: ['Preço', 'Quantidade em estoque']
# Nome: {'empresa': 'Senai_Story', 'marca': 'ti', 'ano': 2025}
# Marca: {'Apple'}
# Ano: 2025
